# %%
import jsonlines
import pandas as pd

# %%
sip = []
with open("C:/Users/user/Desktop/Post/20대/shinbyeong_post.jl", "r+", encoding="utf8") as f:
    for item in jsonlines.Reader(f):
        sip.append(item)
sip = pd.DataFrame(sip)

# %%
cho = []
with open("C:/Users/user/Desktop/Post/20대/신병휴가.jl", "r+", encoding="utf8") as f:
    for item in jsonlines.Reader(f):
        cho.append(item)
cho1 = pd.DataFrame(cho)

# %%
a = []
with open("C:/Users/user/Desktop/Post/20대/신병휴가_2.jl", "r+", encoding="utf8") as f:
    for item in jsonlines.Reader(f):
        a.append(item)
cho4 = pd.DataFrame(a)

# %%
b = []
with open("C:/Users/user/Desktop/Post/20대/신병휴가_3.jl", "r+", encoding="utf8") as f:
    for item in jsonlines.Reader(f):
        b.append(item)
gen10 = pd.DataFrame(b)

# %%
total = pd.concat([sipdae,cho1, cho4, gen10],axis=0)

# %%
total
# Out:
#          inner_id            post_date  view_count  like_count  \
# 0      2522614750  2020-08-07 17:20:35         NaN          54
# 1      2522614750  2020-06-25 12:20:28         NaN          51
# 2      2522614750  2020-06-24 14:44:38         NaN          43
# 3      2522614750  2020-05-03 19:26:04         NaN          46
# 4      2522614750  2020-03-13 21:07:27         NaN          64
# ...           ...                  ...         ...         ...
# 16754  7339243794  2018-04-10 18:55:26         NaN           8
# 16755  7339243794  2018-04-03 19:01:52         NaN          14
# 16756  7339243794  2018-03-29 23:26:03         NaN          23
# 16757  7339243794  2018-03-27 17:56:52         NaN          10
# 16758  7339243794  2018-03-26 19:45:31         NaN          12
#
#                              crawling_time  \
# 0      2020-09-17-Thu Sep 17 13:29:59 2020
# 1      2020-09-17-Thu Sep 17 13:29:59 2020
# 2      2020-09-17-Thu Sep 17 13:29:59 2020
# ...

# %%
total = total[['post_id', 'insta_id', 'inner_id', 'post_date', 'url','content','media_url', 'hashtag', 'location', 'like_count','view_count','crawling_time']]

# %%
total.columns = ['shortcode','insta_id','inner_id','post_date','url','content','media_url','hashtag','region_tag','like_count','view_count','crawling_time']

# %%
total['team_idx'] = '1'
# Out:
# <ipython-input-173-65b69c7e9113>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total['team_idx'] = '1'

# %%
total['age'] = 20
total['gender'] = 'M'
# Out:
# <ipython-input-174-95c72458a3f4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total['age'] = 20
# <ipython-input-174-95c72458a3f4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total['gender'] = 'M'

# %%
total = total.drop_duplicates('shortcode', keep='first')

# %%
total.to_csv('C:\\Users\\user\\Desktop\\전처리데이터\\post\\isipdae_nam.csv', index=False, encoding='utf-8')

# %%
pd.read_csv('C:\\Users\\user\\Desktop\\전처리데이터\\post\\isipdae_nam.csv')
# Out:
#          shortcode        insta_id    inner_id            post_date  \
# 0      CDlMej0pG-K  sun_woo5667782  2522614750  2020-08-07 17:20:35
# 1      CB178xdJ_89  sun_woo5667782  2522614750  2020-06-25 12:20:28
# 2      CBznp2opsed  sun_woo5667782  2522614750  2020-06-24 14:44:38
# 3      B_uOhliHP_p  sun_woo5667782  2522614750  2020-05-03 19:26:04
# 4      B9rFlnmJpuC  sun_woo5667782  2522614750  2020-03-13 21:07:27
# ...            ...             ...         ...                  ...
# 55130  BhYrpj9Hc1t   gong.jeonggyu  7339243794  2018-04-10 18:55:26
# 55131  BhGq0iJnMUc   gong.jeonggyu  7339243794  2018-04-03 19:01:52
# 55132  Bg6RFDFnOJL   gong.jeonggyu  7339243794  2018-03-29 23:26:03
# 55133  Bg0h0XXno_D   gong.jeonggyu  7339243794  2018-03-27 17:56:52
# 55134  BgyJdPqnjFy   gong.jeonggyu  7339243794  2018-03-26 19:45:31
#
#                                            url  \
# 0      https://www.instagram.com/p/CDlMej0pG-K
# 1      https://www.instagram.com/p/CB178xdJ_89
# ...
