# %%
import pandas as pd

# %%
a = pd.read_csv('C:/Users/Inyong Kim/Desktop/구로2009.csv', encoding='euc-kr')
b = pd.read_csv('C:/Users/Inyong Kim/Desktop/구로2012.csv', encoding='euc-kr')
c = pd.read_csv('C:/Users/Inyong Kim/Desktop/구로2015.csv', encoding='euc-kr')
d = pd.read_csv('C:/Users/Inyong Kim/Desktop/구로2018.csv', encoding='euc-kr')
e = pd.read_csv('C:/Users/Inyong Kim/Desktop/구로2019.csv', encoding='euc-kr')

# %%
total = pd.concat([a,b,c,d,e], axis=0,ignore_index=True)
total
# Out:
#                 사고번호               사고일시   요일             시군구    사고내용  사망자수  \
# 0   2007110700100257   2007년 11월 7일 14시  수요일  서울특별시 구로구 신도림동    중상사고     0
# 1   2008011000100260   2008년 1월 10일 16시  목요일   서울특별시 구로구 오류동    경상사고     0
# 2   2008030500100111    2008년 3월 5일 08시  수요일   서울특별시 구로구 고척동    중상사고     0
# 3   2008110600100114   2008년 11월 6일 08시  목요일   서울특별시 구로구 오류동    중상사고     0
# 4   2009051400100361   2009년 5월 14일 16시  목요일   서울특별시 구로구 구로동    중상사고     0
# ..               ...                ...  ...             ...     ...   ...
# 80  2019063000100176   2019년 6월 30일 12시  일요일   서울특별시 구로구 구로동    경상사고     0
# 81  2019081200100520   2019년 8월 12일 17시  월요일   서울특별시 구로구 오류동    중상사고     0
# 82  2019090600100329    2019년 9월 6일 15시  금요일   서울특별시 구로구 오류동    경상사고     0
# 83  2019111000100231  2019년 11월 10일 13시  일요일   서울특별시 구로구 천왕동    경상사고     0
# 84  2019113000100246  2019년 11월 30일 11시  토요일   서울특별시 구로구 고척동  부상신고사고     0
#
# ...

# %%
total.to_csv('C:/Users/Inyong Kim/Desktop/구로.csv', index=False, encoding='euc-kr')

# %%
pd.read_csv('C:/Users/Inyong Kim/Desktop/구로.csv', encoding='euc-kr')
# Out:
#                 사고번호               사고일시   요일             시군구    사고내용  사망자수  \
# 0   2007110700100257   2007년 11월 7일 14시  수요일  서울특별시 구로구 신도림동    중상사고     0
# 1   2008011000100260   2008년 1월 10일 16시  목요일   서울특별시 구로구 오류동    경상사고     0
# 2   2008030500100111    2008년 3월 5일 08시  수요일   서울특별시 구로구 고척동    중상사고     0
# 3   2008110600100114   2008년 11월 6일 08시  목요일   서울특별시 구로구 오류동    중상사고     0
# 4   2009051400100361   2009년 5월 14일 16시  목요일   서울특별시 구로구 구로동    중상사고     0
# ..               ...                ...  ...             ...     ...   ...
# 80  2019063000100176   2019년 6월 30일 12시  일요일   서울특별시 구로구 구로동    경상사고     0
# 81  2019081200100520   2019년 8월 12일 17시  월요일   서울특별시 구로구 오류동    중상사고     0
# 82  2019090600100329    2019년 9월 6일 15시  금요일   서울특별시 구로구 오류동    경상사고     0
# 83  2019111000100231  2019년 11월 10일 13시  일요일   서울특별시 구로구 천왕동    경상사고     0
# 84  2019113000100246  2019년 11월 30일 11시  토요일   서울특별시 구로구 고척동  부상신고사고     0
#
# ...
