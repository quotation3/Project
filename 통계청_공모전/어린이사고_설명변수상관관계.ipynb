# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rc('font', family='NanumGothic')

# %%
df = pd.read_csv('C:/Users/Inyong Kim/Desktop/2019_구별_사고통계.csv', encoding='euc-kr')
df
# Out:
#    행정구역별(읍면동)  10대인구   10대인구비율  어린이보호구역사고건수  어린이사고건수  어린이사상자수
# 0         종로구  12677  0.081803            0       20        7
# 1          중구  10595  0.080904            0       24        6
# 2         용산구  22910  0.100845            2       27       11
# 3         성동구  30824  0.102854            1       45       15
# 4         광진구  33413  0.092874            6       45       30
# 5        동대문구  32595  0.091793            3       41       20
# 6         중랑구  36696  0.094986            3       65       30
# 7         성북구  47256  0.106115            8       59       23
# 8         강북구  27112  0.089222            5       59       22
# 9         도봉구  31743  0.098111            8       42       18
# 10        노원구  59133  0.113178            6       74       28
# 11        은평구  48606  0.105315            6       55       30
# 12       서대문구  30595  0.095791            0       43       16
# 13        마포구  39238  0.106242            2       45       14
# 14        양천구  55734  0.126566            8       81       41
# 15        강서구  64120  0.111688           16       90       43
# 16        구로구  45996  0.105602           13       81       44
# 17        금천구  21545  0.086267            1       30       18
# 18       영등포구  37390  0.094878            2       74       33
# 19        동작구  38632  0.096491            4       57       24
# 20        관악구  38026  0.074880            3       37       15
# 21        서초구  54510  0.134606            3       69       21
# 22        강남구  61474  0.120727            6      107       44
# 23        송파구  78894  0.121637            4      136       56
# 24        강동구  47202  0.113661            4       69       35

# %%
corr = df.corr(method = 'pearson')
corr
# Out:
#                 10대인구   10대인구비율  어린이보호구역사고건수   어린이사고건수   어린이사상자수
# 10대인구        1.000000  0.800869     0.563111  0.906012  0.838688
# 10대인구비율      0.800869  1.000000     0.392369  0.716455  0.614914
# 어린이보호구역사고건수  0.563111  0.392369     1.000000  0.498280  0.625355
# 어린이사고건수      0.906012  0.716455     0.498280  1.000000  0.927776
# 어린이사상자수      0.838688  0.614914     0.625355  0.927776  1.000000

# %%
df_heatmap = sns.heatmap(corr, cbar = True, annot = True, annot_kws={'size' : 10}, fmt = '.2f', square = True, cmap = 'Blues')
