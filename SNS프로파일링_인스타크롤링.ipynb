# %%
# -*- coding: utf-8 -*-
import requests
import re
import json
import urllib
import datetime
from bs4 import BeautifulSoup

#search = '%EC%9D%B4%EC%8A%B9%EA%B8%B0'
def insta(query):
    search = urllib.parse.quote(query)

    headers = {'x-instagram-gis': 'ad034c3799ec2a9b083be2bbb257ffec',
               'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36'}

    response = requests.get('https://www.instagram.com/explore/tags/' + search + '/?__a=1')
    json = response.json()

    for data in json['graphql']['hashtag']['edge_hashtag_to_media']['edges']:
        
        #print(data['node']['id'])
        #print(data['node']['is_video'])
        print("작성자 : ", data['node']['owner']['id'])
        print("작성일 : ", datetime.datetime.fromtimestamp(int(data['node']['taken_at_timestamp'])).strftime('%Y-%m-%d %H:%M:%S'))
        print("내용 : ", data['node']['edge_media_to_caption']['edges'][0]['node']['text'].strip())
        #print(len(data['node']['edge_media_to_caption']['edges']))
        print('')
        print('')

    max_id = json['graphql']['hashtag']['edge_hashtag_to_media']['edges'][len(json['graphql']['hashtag']['edge_hashtag_to_media']['edges']) - 1]['node']['id']
    is_next = True

    while is_next:
        print('https://www.instagram.com/explore/tags/' + search + '/?__a=1&max_id=' + max_id)
        response2 = requests.get('https://www.instagram.com/explore/tags/' + search + '/?__a=1&max_id=' + max_id, headers = headers)
        json2 = response2.json()

        for data in json2['graphql']['hashtag']['edge_hashtag_to_media']['edges']:

            #print(data['node']['id'])
            #print(data['node']['is_video'])
            print("작성자 : ", data['node']['owner']['id'])
            print("작성일 : ", datetime.datetime.fromtimestamp(int(data['node']['taken_at_timestamp'])).strftime('%Y-%m-%d %H:%M:%S'))
            print("내용 : ", data['node']['edge_media_to_caption']['edges'][0]['node']['text'].strip())
            #print(len(data['node']['edge_media_to_caption']['edges']))
            print('')
            print('')

        try:
            max_id = json2['graphql']['hashtag']['edge_hashtag_to_media']['edges'][len(json2['graphql']['hashtag']['edge_hashtag_to_media']['edges']) - 1]['node']['id']
        except:
            is_next = False


insta("김인용")
# Out:
# 작성자 :  19476590358
# 작성일 :  2020-07-22 17:02:45
# 내용 :  비오는 오늘 프라이브는 열심히 촬영중 🎥
# 어떤 촬영을 하고 있었을까요?
#
# 곧 올라갈 영상을 기대해주세요😉
#
#
# 작성자 :  5393891324
# 작성일 :  2020-05-29 01:35:34
# 내용 :  Project Album 'Rock in Korea' - 1989
# Vinyl : 성음레코드(1989). CD : Jave Music(2002)
#
# 1986년, 시나위의 데뷰앨범으로 시작한 우리나라 헤비메틀의 전성기는 허무함마저 느껴질만큼 너무나 짧았다.
#
# 고작 만 삼년이 지나자 쇠퇴의 기미가 보이는 헤비메틀을 중흥시키려 업계의 중견과 신진세력이 뭉쳐 프로젝트 앨범을 만들었는데 이것이 바로 'Rock in Korea' 이다.
#
# 이보다 한 해 앞선 1988년에 대도레코드에서 먼저 'Friday Afternoon'이라는 타이틀로 헤비메틀 프로젝트 앨범을 발매했었는데 'Black Syndrome'을 제외하고는 '철장미(Iron Rose)', 'Cratia', 'Avalanche'등의 신인밴드들이 주축을 이루었던데 반해 이 'Rock in Korea'의 경우는 김도균, 임재범, 김종서, 강기영등의 거물들을 비롯해 공식적인 자리에 본인을 드러내는 것을 극도로 꺼려하던 '재야의 은둔고수' 이중산이 참여하여 관심을 끌었다.
#
# 그런데 이 앨범에서 가장 눈에 띄는 활약을 펼친 것은 그들이 아닌, '공중전화'라는 신인밴드의 리더이자 기타리스트인 '오태호'였다.
#
# 이 앨범에서 테크니컬한 기타 연주와 작곡능력으로 일찌감치 싹수를 보인 그가 90년대 들어 대중음악 작곡가로 변신하여 '이승환'과의 컬래버레이션(이오공감)으로 당대를 풍미했던 것은 결코 우연이나 행운이 아니었던 것이다.
#
# 김도균과 임재범은 의기투합하여 헤비메틀의 본바닥인 영국으로 건너가 '사랑'이라는 밴드로 활동하다 한계를 느끼고 국내로 복귀해 'Asiana'를 결성하게 된다.
#
# 많은 사람들이 이 앨범에서 김도균과 임재범의 호흡이 잘 맞아 떨어진 타이틀 트랙, 'Rock in Korea'와 'Same Old Story'를 꼽지만 나는 앨범의 시작을 알리는 '멈추지않는 강'을 엄지손가락에 놓는다.
#
# 강기영(후에 달파란이 되는)의 작곡과 Bass 연주에 김성헌의 보컬, 한정호(Keyboard)와 이병일(Drum)이 가세했고 기타를 이중산과 오태호가 맡았다.
#
# 원래 이중산은 '파라다이스'와 '기억날 그 날이 와도'에서의 어쿠스틱 기타 연주 정도로 끝내고 후배들에게 양보를 하려 했는데 애들 잘하고 있나 보러 스튜디오에 놀러왔다가 이 곡의 사운드가 조금 비는 듯한 느낌에 비치되어 있던 저가형 기타로, 연습없이 한 번에...One Take로 연주한 것이 이 곡의 가치를 높여주는 결과가 되었다.
#
# 물 흐르듯 유려하지만 예측하기 어려운 Backing과 중간 솔로 연주의 첫부분을 연주한 오태호의 패기도 놀랍지만 브리지마다 송곳으로 찌르듯이 치고 들어오며 간주의 두 번째 파트와 하일라이트 부분에서 곡의 분위기를 최대한 상승시키는 호소력 넘치는 솔로는 '전설의 고수'다운 면모를 유감없이 보여준다.
#
# 이 비장미 만빵의 곡을 제대로 살려주는 또하나의 존재가 '김성헌'인데 파워풀한 볼륨감의 목소리가 넓은 음역대에서 안정적으로 진행된다.
#
# 멈추지않는 강처럼 대한민국 롹을 이어가겠다는 강력한 의지가 돋보이는 이들의 분전은 일단 실패로 돌아갔다.
#
# 나는 이 앨범과 이 곡을 들을때마다 그때가 생각나며 조금 서글퍼지기도 하는데 오늘은 그 '위대한 실패자'들의 이름을 한명 한명 소개해 보겠다.
#
# #이중산
#
# #이병일 #한정호  #사랑과평화
#
# #김도균  #백두산  #강기영  #H2O
#
# #임재범 #손무현  #외인부대
#
# #김종서 #김민기 #카리스마
#
# #김성헌 #손경호  #시나위
#
# #박현준  #작은하늘 #김인용  #어린왕자
#
# #오태호 #홍성민  #공중전화
#
# #Lorren Scott #TerryScherrer # 마쥬르카
#
# 그런데 신대철, 김태원, 이근형등은 왜 빠졌을까...스케쥴 때문에...?
#
# #락인코리아 #RockinKorea #KoreanHeavyMetal #VinylRecordsCollection
#
#
# 작성자 :  1423834029
# 작성일 :  2020-02-22 19:47:01
# 내용 :  쓸수록 좋아지는 다완
# 내일은 말차 한사발!
# .
# .
# .
# #tea #茶
# #조성주 #교맥다완 #소바다완 #趙誠主 #蕎麥茶碗
# #용도예 #김인용 #시노다관 #茶道 #다도
# #大红袍 #대홍포 #建盏 #李达 #건잔
#
#
# 작성자 :  1423834029
# 작성일 :  2020-02-21 22:33:55
# 내용 :  주인님의 애프터눈티 vs 나의 애프터눈티
# 내가 진거 같은 느낌 같은 느낌.......^^;
# .
# .
# .
# #afternoontea #下午茶 #tea #茶
